# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=(12,7)
plt.rcParams['figure.dpi']=150

# %%
df=pd.read_csv(r'C:\Users\Sarvadnya\FUSIONCLASS\machine_learning\dataset\Student_Performance.csv')
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(127)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (9873, 6)

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'],inplace=True)

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9868              1               49                        Yes            4
# 9869              7               64                        Yes            8
# 9870              6               83                        Yes            8
# 9871              9               97                        Yes            7
# 9872              7               74                         No            8
#
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df=pd.get_dummies(data=df,columns=['Extracurricular Activities'],dtype=int)
df # one hot encoding # x columns ( independent variables )
# y column (dependent variable) always # label scalling
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9868              1               49            4
# 9869              7               64            8
# 9870              6               83            8
# 9871              9               97            7
# 9872              7               74            8
#
#       Sample Question Papers Practiced  Performance Index  \
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...

# %% [markdown]
# # defining x and y

# %%
x =df.drop(columns=['Performance Index'])
y =df['Performance Index']

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9868              1               49            4
# 9869              7               64            8
# 9870              6               83            8
# 9871              9               97            7
# 9872              7               74            8
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 0                                    1                              0
# 1                                    2                              1
# 2                                    2                              0
# 3                                    2                              0
# ...

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9868    23.0
# 9869    58.0
# 9870    74.0
# 9871    95.0
# 9872    64.0
# Name: Performance Index, Length: 9873, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler # Feature scalling

# %%
sc=StandardScaler()

# %%
x = pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0          0.775566         1.706168     1.454025
# 1         -0.383205         0.724912    -1.491315
# 2          1.161822        -1.064438     0.275889
# 3          0.003052        -1.006717    -0.902247
# 4          0.775566         0.320865     0.864957
# ...             ...              ...          ...
# 9868      -1.541976        -1.179880    -1.491315
# 9869       0.775566        -0.314066     0.864957
# 9870       0.389309         0.782633     0.864957
# 9871       1.548079         1.590727     0.275889
# 9872       0.775566         0.263144     0.864957
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 0                            -1.249715                      -1.010078
# 1                            -0.900925                       0.990022
# 2                            -0.900925                      -1.010078
# 3                            -0.900925                      -1.010078
# ...

# %% [markdown]
# # spliting the data into training and test part

# %%
from sklearn.model_selection  import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.7)

# %%
ytest
# Out:
# 7667    74.0
# 7324    74.0
# 4111    32.0
# 3828    52.0
# 6388    26.0
#         ...
# 5798    82.0
# 7364    20.0
# 7258    91.0
# 7906    55.0
# 5776    76.0
# Name: Performance Index, Length: 2962, dtype: float64

# %% [markdown]
# # model building

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.coef_ # slope (m)
# Out:
# array([ 7.37683124, 17.6665054 ,  0.81252912,  0.53987046, -0.14727237,
#         0.14727237])

# %%
lr.intercept_ #(c)
# Out:
# np.float64(55.238233988762175)

# %%
x.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Sleep Hours',
#        'Sample Question Papers Practiced', 'Extracurricular Activities_No',
#        'Extracurricular Activities_Yes'],
#       dtype='object')

# %%
lr.predict(xtest)
# Out:
# array([74.17091189, 73.49744244, 30.93847213, ..., 89.45816586,
#        58.2627756 , 77.10517946])

# %%
ytest
# Out:
# 7667    74.0
# 7324    74.0
# 4111    32.0
# 3828    52.0
# 6388    26.0
#         ...
# 5798    82.0
# 7364    20.0
# 7258    91.0
# 7906    55.0
# 5776    76.0
# Name: Performance Index, Length: 2962, dtype: float64

# %%
ypred=lr.predict(xtest)
ypred
# Out:
# array([74.17091189, 73.49744244, 30.93847213, ..., 89.45816586,
#        58.2627756 , 77.10517946])

# %% [markdown]
# # getting prediction for new test data

# %%
xtest
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 7667       1.161822         0.667191    -1.491315
# 7324      -0.383205         1.186680    -0.313179
# 4111      -1.155719        -0.833555    -1.491315
# 3828       0.003052        -0.025461    -0.313179
# 6388      -0.769462        -1.353043    -1.491315
# ...             ...              ...          ...
# 5798       0.775566         1.128959     0.275889
# 7364      -1.155719        -1.237601    -1.491315
# 7258       0.775566         1.590727    -0.902247
# 7906       0.775566        -0.256345     0.864957
# 5776       1.161822         0.724912     0.864957
#
#       Sample Question Papers Practiced  Extracurricular Activities_No  \
# 7667                          0.145444                       0.990022
# 7324                          0.145444                      -1.010078
# 4111                          0.843023                       0.990022
# 3828                         -1.598505                      -1.010078
# ...

# %%
ytest # actual value
# Out:
# 7667    74.0
# 7324    74.0
# 4111    32.0
# 3828    52.0
# 6388    26.0
#         ...
# 5798    82.0
# 7364    20.0
# 7258    91.0
# 7906    55.0
# 5776    76.0
# Name: Performance Index, Length: 2962, dtype: float64

# %%
ypred=lr.predict(xtest)
ypred
# Out:
# array([74.17091189, 73.49744244, 30.93847213, ..., 89.45816586,
#        58.2627756 , 77.10517946])

# %% [markdown]
# # evaluatuing  the linear regression model

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mse=mean_squared_error(ytest,ypred)
mse
# Out:
# 4.1299359913152465

# %%
np.sqrt(mse) # error
# Out:
# np.float64(2.032224394921793)

# %%
r2_score(ytest,ypred) # accuracy
# Out:
# 0.9887454493927796
